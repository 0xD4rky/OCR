# %%
## requirements

# !absl-py == 2.1.0
# !astunparse == 1.6.3
# !gast == 0.4.0
# !imutils == 0.5.4
# !numpy == 1.23.5
# !oauthlib == 3.2.2
# !openapi-schema-pydantic == 1.2.4
# !opencv-contrib-python == 4.6.0.66
#opencv-python == 4.8.1.78
# !opencv-python-headless == 4.10.0.84
# !penpyxl == 3.1.5
# !packaging == 23.1
# !paddleocr == 2.7.3
# !paddlepaddle == 2.6.1
# !paddlepaddle-gpu == 2.6.1
# !pandas == 2.0.3
# !pdf2docx == 0.5.8z
# !pdf2image == 1.17.0
# !Pillow == 10.0.0
# !pip == 24.0
# !poppler-utils == 0.1.0
#proto-plus == 1.24.0
# !protobuf<=3.20.2
# !PyMuPDF == 1.24.7
# !PyMuPDFb == 1.24.6
# !pyparsing == 3.1.2
# !pytesseract == 0.3.10
# !python-dateutil == 2.9.0.post0
# !python-docx == 1.1.2
# !requests == 2.31.0
# !requests-oauthlib == 2.0.0
# !streamlit
# !tensorflow == 2.10.1
#tensorflow-datasets == 4.9.2
#tensorflow-estimator == 2.10.0
#tensorflow-intel == 2.13.0
#tensorflow-io-gcs-filesystem == 0.31.0
# !toml == 0.10.2
# !torch == 2.0.1
# !torchaudio == 2.0.2
# !torchvision == 0.15.2
# !tornado == 6.4.1
# !urllib3 == 1.25.11
# !wheel == 0.43.0
# !wrapt == 1.14.0
# !distutils


# Download

# Poppler: Download from Poppler, and add the lib and bin paths to the environment variables.

# cuDNN: Download from NVIDIA cuDNN, and add the bin and lib paths to the environment variables.
# Out:
# /bin/bash: line 1: absl-py: command not found
# /bin/bash: line 1: astunparse: command not found
# /bin/bash: line 1: gast: command not found
# /bin/bash: line 1: imutils: command not found
# /bin/bash: line 1: numpy: command not found
# /bin/bash: line 1: oauthlib: command not found
# /bin/bash: line 1: openapi-schema-pydantic: command not found
# /bin/bash: line 1: opencv-contrib-python: command not found
# /bin/bash: line 1: opencv-python-headless: command not found
# /bin/bash: line 1: penpyxl: command not found
# /bin/bash: line 1: packaging: command not found
# /bin/bash: line 1: paddleocr: command not found
# /bin/bash: line 1: paddlepaddle: command not found
# /bin/bash: line 1: paddlepaddle-gpu: command not found
# /bin/bash: line 1: pandas: command not found
# /bin/bash: line 1: pdf2docx: command not found
# /bin/bash: line 1: pdf2image: command not found
# /bin/bash: line 1: Pillow: command not found
# ERROR: unknown command "=="
# /bin/bash: line 1: poppler-utils: command not found
# /bin/bash: line 1: =3.20.2: No such file or directory
# /bin/bash: line 1: PyMuPDF: command not found
# /bin/bash: line 1: PyMuPDFb: command not found
# /bin/bash: line 1: pyparsing: command not found
# /bin/bash: line 1: pytesseract: command not found
# /bin/bash: line 1: python-dateutil: command not found
# /bin/bash: line 1: python-docx: command not found
# /bin/bash: line 1: requests: command not found
# /bin/bash: line 1: requests-oauthlib: command not found
# /bin/bash: line 1: streamlit: command not found
# /bin/bash: line 1: tensorflow: command not found
# /bin/bash: line 1: toml: command not found
# /bin/bash: line 1: torch: command not found
# /bin/bash: line 1: torchaudio: command not found
# /bin/bash: line 1: torchvision: command not found
# /bin/bash: line 1: tornado: command not found
# /bin/bash: line 1: urllib3: command not found
# usage: wheel [-h] {unpack,pack,convert,tags,version,help} ...
# wheel: error: argument {unpack,pack,convert,tags,version,help}: invalid choice: '==' (choose from 'unpack', 'pack', 'convert', 'tags', 'version', 'help')
# /bin/bash: line 1: wrapt: command not found
# /bin/bash: line 1: distutils: command not found

# %%
# !pip install paddleocr
# Out:
# Collecting paddleocr
#   Downloading paddleocr-2.8.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.23.2)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr) (0.4.0)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.66.5)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (1.26.4)
# Collecting rapidfuzz (from paddleocr)
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddleocr) (9.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr) (6.0.2)
# Collecting python-docx (from paddleocr)
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr) (4.53.1)
# Collecting fire>=0.3.0 (from paddleocr)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (3.7.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->paddleocr) (2.34.2)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (3.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->paddleocr) (2024.8.30)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Downloading paddleocr-2.8.1-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 10.9 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 18.4 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 28.1 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 15.4 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 62.3 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=4f4cbc85349770ac7b3b969aa8525c62251e63f3468581ea6aafd52abc4b2b0b
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: pyclipper, lmdb, rapidfuzz, python-docx, fire, paddleocr
# Successfully installed fire-0.6.0 lmdb-1.5.1 paddleocr-2.8.1 pyclipper-1.3.0.post5 python-docx-1.1.2 rapidfuzz-3.9.7

# %%
# !pip install paddlepaddle
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Collecting httpx (from paddlepaddle)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (9.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (4.4.2)
# Collecting astor (from paddlepaddle)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle) (3.20.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (2024.8.30)
# Collecting httpcore==1.* (from httpx->paddlepaddle)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (3.8)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->paddlepaddle)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Downloading paddlepaddle-2.6.2-cp310-cp310-manylinux1_x86_64.whl (126.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 5.6 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.2 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 986.6 kB/s eta 0:00:00
# Installing collected packages: h11, astor, httpcore, httpx, paddlepaddle
# Successfully installed astor-0.8.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 paddlepaddle-2.6.2

# %%
import cv2  # For image processing
import numpy as np  # For array operations
import tensorflow as tf  # For non-maximum suppression
import csv  # For writing data to CSV
from paddleocr import PaddleOCR  # For OCR

ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Initialize PaddleOCR
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:00<00:00, 7.30MiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:00<00:00, 17.3MiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:00<00:00, 4.38MiB/s]
# [2024/09/14 13:50:38] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/usr/local/lib/python3.10/dist-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
import pandas as pd

# %% [markdown]
# def align_columns(out_array):
#     """
#     Align columns in the 2D array by shifting text left if the adjacent column is empty.
#
#     :param out_array: 2D array of text data.
#     :return: Aligned 2D array.
#     """
#     df = pd.DataFrame(out_array)  # Convert to DataFrame
#     for i in range(1, df.shape[1]):  # Iterate through columns
#         for j in range(df.shape[0]):  # Iterate through rows
#             if df.iloc[j, i] and not df.iloc[j, i - 1]:  # If current cell has value but previous cell is empty
#                 df.iloc[j, i - 1] = df.iloc[j, i]  # Move value to previous cell
#                 df.iloc[j, i] = ""  # Clear current cell
#     return df.values
#
# def remove_incomplete_duplicates(out_array):
#     """
#     Remove columns with incomplete or duplicate data from the 2D array.
#
#     :param out_array: 2D array of text data.
#     :return: Cleaned 2D array.
#     """
#     df = pd.DataFrame(out_array)  # Convert to DataFrame
#     df_cleaned = df.copy()  # Copy DataFrame for cleaning
#     for col in df.columns:
#         if df[col].isnull().sum() > 0:  # Check if column has any null values
#             df_cleaned = df_cleaned.drop(columns=[col])  # Drop columns with null values
#     return df_cleaned.values

# %%
def align_columns(out_array):
  """ Align columns in the 2D array by shifting text left if the adjacent column is empty.

  :param out_array: 2D array of text data.
  :return: Aligned 2D array.
  """
  df = pd.DataFrame(out_array)  # Convert to DataFrame
  for i in range(1, df.shape[1]):  # Iterate through columns
      for j in range(df.shape[0]):  # Iterate through rows
          if df.iloc[j, i] and not df.iloc[j, i - 1]:  # If current cell has value but previous cell is empty
              df.iloc[j, i - 1] = df.iloc[j, i]  # Move value to previous cell
              df.iloc[j, i] = ""  # Clear current cell
  return df.values

# %%
def remove_incomplete_duplicates(out_array):
  """ Remove columns with incomplete or duplicate data from the 2D array.

  :param out_array: 2D array of text data.
  :return: Cleaned 2D array.
  """
  df = pd.DataFrame(out_array)  # Convert to DataFrame
  df_cleaned = df.copy()  # Copy DataFrame for cleaning
  for col in df.columns:
      if df[col].isnull().sum() > 0:  # Check if column has any null values
          df_cleaned = df_cleaned.drop(columns=[col])  # Drop columns with null values
  return df_cleaned.values

# %%
def ocr_to_csv(url, csv_file_path):
    """
    Perform OCR on the image and save the extracted text to a CSV file.

    :param image_path: Path to the input image file.
    :param csv_file_path: Path where the CSV file will be saved.
    """

    image = fetch_image(url)
    image_cv = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # Convert image to OpenCV format

    image_height, image_width = image_cv.shape[:2]  # Get image dimensions
    output = ocr.ocr(image_cv)[0]  # Perform OCR using PaddleOCR
    # boxes = [line[0] for line in output]  # Extract bounding boxes
    # texts = [line[1][0] for line in output]  # Extract text
    # probabilities = [line[1][1] for line in output]  # Extract probabilities
    if output:
      for line in output[0]:
        boxes = [line[0] for line in output]
        # Extract text, use an empty string if text is None or empty
        texts = [line[1][0] for line in output]
        probabilities = [line[1][1] for line in output]  # Extract probabilities
    else:
      # If no OCR output, consider adding default values or handling as needed
      boxes = [[[0, 0], [0, 0], [0, 0], [0, 0]]]
      texts = [""]
      probabilities = [0.0]
      # Draw bounding boxes and text on the image

    image_boxes = image_cv.copy()
    for box, text in zip(boxes, texts):
        cv2.rectangle(image_boxes, (int(box[0][0]), int(box[0][1])), (int(box[2][0]), (int(box[2][1]))), (0, 0, 255), 1)
        cv2.putText(image_boxes, text, (int(box[0][0]), int(box[0][1])), cv2.FONT_HERSHEY_SIMPLEX, 1, (222, 0, 0), 1)

    # Prepare boxes for non-maximum suppression
    horiz_boxes, vert_boxes = [], []
    for box in boxes:
        x_h, x_v = 0, int(box[0][0])
        y_h, y_v = int(box[0][1]), 0
        width_h, width_v = image_width, int(box[2][0] - box[0][0])
        height_h, height_v = int(box[2][1] - box[0][1]), image_height
        horiz_boxes.append([x_h, y_h, x_h + width_h, y_h + height_h])
        vert_boxes.append([x_v, y_v, x_v + width_v, y_v + height_v])

    # Apply non-maximum suppression to remove redundant boxes
    horiz_out = tf.image.non_max_suppression(
        horiz_boxes,
        probabilities,
        max_output_size=1000,
        iou_threshold=0.1,
        score_threshold=float('-inf')
    )
    horiz_lines = np.sort(np.array(horiz_out))

    vert_out = tf.image.non_max_suppression(
        vert_boxes,
        probabilities,
        max_output_size=1000,
        iou_threshold=0.1,
        score_threshold=float('-inf')
    )
    vert_lines = np.sort(np.array(vert_out))

    # Create a 2D array to store text aligned by rows and columns
    out_array = [["" for _ in range(len(vert_lines))] for _ in range(len(horiz_lines))]
    unordered_boxes = [vert_boxes[i][0] for i in vert_lines]
    ordered_boxes = np.argsort(unordered_boxes)

    def intersection(box_1, box_2):
        """Compute intersection of two bounding boxes."""
        return [box_2[0], box_1[1], box_2[2], box_1[3]]

    def iou(box_1, box_2):
        """Calculate Intersection over Union (IoU) of two bounding boxes."""
        x_1 = max(box_1[0], box_2[0])
        y_1 = max(box_1[1], box_2[1])
        x_2 = min(box_1[2], box_2[2])
        y_2 = min(box_1[3], box_2[3])
        inter = abs(max((x_2 - x_1, 0)) * max((y_2 - y_1, 0)))
        if inter == 0:
            return 0
        box_1_area = abs((box_1[2] - box_1[0]) * (box_1[3] - box_1[1]))
        box_2_area = abs((box_2[2] - box_2[0]) * (box_2[3] - box_2[1]))
        return inter / float(box_1_area + box_2_area - inter)

    # Fill in the out_array with detected text
    for i in range(len(horiz_lines)):
        for j in range(len(vert_lines)):
            resultant = intersection(horiz_boxes[horiz_lines[i]], vert_boxes[vert_lines[ordered_boxes[j]]])
            for b in range(len(boxes)):
                the_box = [boxes[b][0][0], boxes[b][0][1], boxes[b][2][0], boxes[b][2][1]]
                if iou(resultant, the_box) > 0.1:
                    out_array[i][j] = texts[b]

    out_array = np.array(out_array)

    # Post-process the array to align columns correctly and remove incomplete duplicates
    out_array = align_columns(out_array)
    out_array = remove_incomplete_duplicates(out_array)

    # Save the processed data to a CSV file
    with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerows(out_array)
    print(f"Data successfully saved to {csv_file_path}")

# %%
import requests
from io import BytesIO

# %%
def fetch_image(url):
    """
    Fetch image from the provided URL.
    """
    response = requests.get(url)
    image = cv2.imdecode(np.frombuffer(response.content, np.uint8), cv2.IMREAD_COLOR)
    if image is None:
        raise ValueError("Failed to decode the image from the provided URL.")
    return image

# %%
import os
if not os.path.exists('test_output'):
    # Create the directory only if it doesn't exist
    os.mkdir('test_output')

# %%
df = pd.read_csv('/content/100rows.csv')
len(df)
# Out:
# 99

# %%
df['image_link'].nunique()
# Out:
# 97

# %%
df = pd.read_csv('/content/100rows.csv')
for i in range(len(df)):
  f"THE ITERATION IS {i}"
  ocr_to_csv(df['image_link'][i],'/content/save.csv')
  df1 = pd.read_csv('/content/save.csv')
  df1.to_csv(f"test_output/{df['image_link'].apply(lambda x: x[36:-4])[i]}.txt", sep=' ', index=False, header=False)
# Out:
# [2024/09/14 14:07:24] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.288867712020874
# [2024/09/14 14:07:24] ppocr DEBUG: cls num  : 17, elapsed : 0.04245924949645996
# [2024/09/14 14:07:25] ppocr DEBUG: rec_res num  : 17, elapsed : 1.078625202178955
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:26] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.27211761474609375
# [2024/09/14 14:07:26] ppocr DEBUG: cls num  : 18, elapsed : 0.03846549987792969
# [2024/09/14 14:07:29] ppocr DEBUG: rec_res num  : 18, elapsed : 3.2026898860931396
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:29] ppocr DEBUG: dt_boxes num : 53, elapsed : 0.29022884368896484
# [2024/09/14 14:07:29] ppocr DEBUG: cls num  : 53, elapsed : 0.12072229385375977
# [2024/09/14 14:07:35] ppocr DEBUG: rec_res num  : 53, elapsed : 5.579114198684692
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:36] ppocr DEBUG: dt_boxes num : 42, elapsed : 0.4296138286590576
# [2024/09/14 14:07:36] ppocr DEBUG: cls num  : 42, elapsed : 0.1661529541015625
# [2024/09/14 14:07:42] ppocr DEBUG: rec_res num  : 42, elapsed : 6.483368396759033
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:43] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.35399866104125977
# [2024/09/14 14:07:43] ppocr DEBUG: cls num  : 13, elapsed : 0.06027364730834961
# [2024/09/14 14:07:43] ppocr DEBUG: rec_res num  : 13, elapsed : 0.7584035396575928
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:44] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.2803313732147217
# [2024/09/14 14:07:44] ppocr DEBUG: cls num  : 17, elapsed : 0.0424189567565918
# [2024/09/14 14:07:45] ppocr DEBUG: rec_res num  : 17, elapsed : 1.1312904357910156
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:45] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.28855347633361816
# [2024/09/14 14:07:46] ppocr DEBUG: cls num  : 37, elapsed : 0.09398126602172852
# [2024/09/14 14:07:50] ppocr DEBUG: rec_res num  : 37, elapsed : 4.355213165283203
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:51] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.42868995666503906
# [2024/09/14 14:07:51] ppocr DEBUG: cls num  : 23, elapsed : 0.08319592475891113
# [2024/09/14 14:07:52] ppocr DEBUG: rec_res num  : 23, elapsed : 1.3682258129119873
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:52] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.29346156120300293
# [2024/09/14 14:07:53] ppocr DEBUG: cls num  : 23, elapsed : 0.057898521423339844
# [2024/09/14 14:07:54] ppocr DEBUG: rec_res num  : 23, elapsed : 1.1881496906280518
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:54] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.2895967960357666
# [2024/09/14 14:07:54] ppocr DEBUG: cls num  : 30, elapsed : 0.07003355026245117
# [2024/09/14 14:07:56] ppocr DEBUG: rec_res num  : 30, elapsed : 1.7923123836517334
# Data successfully saved to /content/save.csv
# [2024/09/14 14:07:56] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.28008317947387695
# [2024/09/14 14:07:56] ppocr DEBUG: cls num  : 7, elapsed : 0.04868793487548828
# [2024/09/14 14:08:00] ppocr DEBUG: rec_res num  : 7, elapsed : 3.9697484970092773
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:01] ppocr DEBUG: dt_boxes num : 22, elapsed : 0.28704380989074707
# [2024/09/14 14:08:01] ppocr DEBUG: cls num  : 22, elapsed : 0.07880878448486328
# [2024/09/14 14:08:02] ppocr DEBUG: rec_res num  : 22, elapsed : 1.307332992553711
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:03] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.4419400691986084
# [2024/09/14 14:08:03] ppocr DEBUG: cls num  : 35, elapsed : 0.15099525451660156
# [2024/09/14 14:08:05] ppocr DEBUG: rec_res num  : 35, elapsed : 2.211036205291748
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:06] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.2821981906890869
# [2024/09/14 14:08:06] ppocr DEBUG: cls num  : 18, elapsed : 0.04208564758300781
# [2024/09/14 14:08:07] ppocr DEBUG: rec_res num  : 18, elapsed : 1.2336716651916504
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:08] ppocr DEBUG: dt_boxes num : 66, elapsed : 0.297579288482666
# [2024/09/14 14:08:08] ppocr DEBUG: cls num  : 66, elapsed : 0.14804697036743164
# [2024/09/14 14:08:11] ppocr DEBUG: rec_res num  : 66, elapsed : 3.7150449752807617
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:12] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.2820436954498291
# [2024/09/14 14:08:12] ppocr DEBUG: cls num  : 30, elapsed : 0.06850385665893555
# [2024/09/14 14:08:14] ppocr DEBUG: rec_res num  : 30, elapsed : 1.7317678928375244
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:14] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.2459118366241455
# [2024/09/14 14:08:14] ppocr DEBUG: cls num  : 10, elapsed : 0.05034470558166504
# [2024/09/14 14:08:15] ppocr DEBUG: rec_res num  : 10, elapsed : 0.46567320823669434
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:15] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.16518926620483398
# [2024/09/14 14:08:15] ppocr DEBUG: cls num  : 39, elapsed : 0.13880658149719238
# [2024/09/14 14:08:19] ppocr DEBUG: rec_res num  : 39, elapsed : 3.964465856552124
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:19] ppocr DEBUG: dt_boxes num : 40, elapsed : 0.19402337074279785
# [2024/09/14 14:08:20] ppocr DEBUG: cls num  : 40, elapsed : 0.10230779647827148
# [2024/09/14 14:08:22] ppocr DEBUG: rec_res num  : 40, elapsed : 2.333583354949951
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:22] ppocr DEBUG: dt_boxes num : 22, elapsed : 0.4077951908111572
# [2024/09/14 14:08:23] ppocr DEBUG: cls num  : 22, elapsed : 0.05830073356628418
# [2024/09/14 14:08:24] ppocr DEBUG: rec_res num  : 22, elapsed : 1.058131456375122
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:24] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.12318038940429688
# [2024/09/14 14:08:24] ppocr DEBUG: cls num  : 4, elapsed : 0.0217437744140625
# [2024/09/14 14:08:24] ppocr DEBUG: rec_res num  : 4, elapsed : 0.2200772762298584
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:24] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.36702942848205566
# [2024/09/14 14:08:25] ppocr DEBUG: cls num  : 15, elapsed : 0.05971050262451172
# [2024/09/14 14:08:26] ppocr DEBUG: rec_res num  : 15, elapsed : 1.250554084777832
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:26] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.2784261703491211
# [2024/09/14 14:08:26] ppocr DEBUG: cls num  : 12, elapsed : 0.028033971786499023
# [2024/09/14 14:08:28] ppocr DEBUG: rec_res num  : 12, elapsed : 1.465606927871704
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:28] ppocr DEBUG: dt_boxes num : 22, elapsed : 0.38119006156921387
# [2024/09/14 14:08:28] ppocr DEBUG: cls num  : 22, elapsed : 0.05852246284484863
# [2024/09/14 14:08:31] ppocr DEBUG: rec_res num  : 22, elapsed : 2.2669453620910645
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:31] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.4436366558074951
# [2024/09/14 14:08:31] ppocr DEBUG: cls num  : 25, elapsed : 0.12786412239074707
# [2024/09/14 14:08:33] ppocr DEBUG: rec_res num  : 25, elapsed : 1.9439842700958252
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:34] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.27716612815856934
# [2024/09/14 14:08:34] ppocr DEBUG: cls num  : 25, elapsed : 0.06698155403137207
# [2024/09/14 14:08:35] ppocr DEBUG: rec_res num  : 25, elapsed : 1.4339814186096191
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:36] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.2807903289794922
# [2024/09/14 14:08:36] ppocr DEBUG: cls num  : 17, elapsed : 0.06506872177124023
# [2024/09/14 14:08:37] ppocr DEBUG: rec_res num  : 17, elapsed : 0.9494094848632812
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:37] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.26982665061950684
# [2024/09/14 14:08:37] ppocr DEBUG: cls num  : 4, elapsed : 0.017998933792114258
# [2024/09/14 14:08:37] ppocr DEBUG: rec_res num  : 4, elapsed : 0.23103713989257812
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:38] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.30194592475891113
# [2024/09/14 14:08:38] ppocr DEBUG: cls num  : 9, elapsed : 0.04975271224975586
# [2024/09/14 14:08:38] ppocr DEBUG: rec_res num  : 9, elapsed : 0.8231759071350098
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:39] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.2756967544555664
# [2024/09/14 14:08:39] ppocr DEBUG: cls num  : 14, elapsed : 0.06037473678588867
# [2024/09/14 14:08:40] ppocr DEBUG: rec_res num  : 14, elapsed : 0.9881551265716553
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:40] ppocr DEBUG: dt_boxes num : 48, elapsed : 0.3053884506225586
# [2024/09/14 14:08:40] ppocr DEBUG: cls num  : 48, elapsed : 0.11130499839782715
# [2024/09/14 14:08:43] ppocr DEBUG: rec_res num  : 48, elapsed : 2.377448081970215
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:43] ppocr DEBUG: dt_boxes num : 43, elapsed : 0.3447139263153076
# [2024/09/14 14:08:43] ppocr DEBUG: cls num  : 43, elapsed : 0.1970362663269043
# [2024/09/14 14:08:47] ppocr DEBUG: rec_res num  : 43, elapsed : 3.6826953887939453
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:48] ppocr DEBUG: dt_boxes num : 22, elapsed : 0.2943916320800781
# [2024/09/14 14:08:48] ppocr DEBUG: cls num  : 22, elapsed : 0.07327771186828613
# [2024/09/14 14:08:49] ppocr DEBUG: rec_res num  : 22, elapsed : 1.2815213203430176
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:49] ppocr DEBUG: dt_boxes num : 19, elapsed : 0.2809903621673584
# [2024/09/14 14:08:49] ppocr DEBUG: cls num  : 19, elapsed : 0.052120208740234375
# [2024/09/14 14:08:51] ppocr DEBUG: rec_res num  : 19, elapsed : 1.174797534942627
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:51] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.2799649238586426
# [2024/09/14 14:08:51] ppocr DEBUG: cls num  : 11, elapsed : 0.04958963394165039
# [2024/09/14 14:08:52] ppocr DEBUG: rec_res num  : 11, elapsed : 0.5792899131774902
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:52] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.2833676338195801
# [2024/09/14 14:08:52] ppocr DEBUG: cls num  : 7, elapsed : 0.03190732002258301
# [2024/09/14 14:08:53] ppocr DEBUG: rec_res num  : 7, elapsed : 0.8525393009185791
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:53] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.28056836128234863
# [2024/09/14 14:08:53] ppocr DEBUG: cls num  : 5, elapsed : 0.01792168617248535
# [2024/09/14 14:08:54] ppocr DEBUG: rec_res num  : 5, elapsed : 0.7702300548553467
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:54] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.27379369735717773
# [2024/09/14 14:08:54] ppocr DEBUG: cls num  : 5, elapsed : 0.017752885818481445
# [2024/09/14 14:08:55] ppocr DEBUG: rec_res num  : 5, elapsed : 0.7151250839233398
# Data successfully saved to /content/save.csv
# [2024/09/14 14:08:55] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.2867085933685303
# [2024/09/14 14:08:55] ppocr DEBUG: cls num  : 18, elapsed : 0.04311370849609375
# [2024/09/14 14:09:00] ppocr DEBUG: rec_res num  : 18, elapsed : 4.752877235412598
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:01] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.42522573471069336
# [2024/09/14 14:09:01] ppocr DEBUG: cls num  : 9, elapsed : 0.06767463684082031
# [2024/09/14 14:09:02] ppocr DEBUG: rec_res num  : 9, elapsed : 0.8650405406951904
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:02] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.719778299331665
# [2024/09/14 14:09:03] ppocr DEBUG: cls num  : 18, elapsed : 0.06554698944091797
# [2024/09/14 14:09:05] ppocr DEBUG: rec_res num  : 18, elapsed : 2.457035541534424
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:06] ppocr DEBUG: dt_boxes num : 73, elapsed : 0.2952277660369873
# [2024/09/14 14:09:06] ppocr DEBUG: cls num  : 73, elapsed : 0.20781517028808594
# [2024/09/14 14:09:12] ppocr DEBUG: rec_res num  : 73, elapsed : 5.870523691177368
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.36251401901245117
# [2024/09/14 14:09:12] ppocr DEBUG: cls num  : 2, elapsed : 0.0319669246673584
# [2024/09/14 14:09:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.137925386428833
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:13] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.34543371200561523
# [2024/09/14 14:09:13] ppocr DEBUG: cls num  : 10, elapsed : 0.0806126594543457
# [2024/09/14 14:09:14] ppocr DEBUG: rec_res num  : 10, elapsed : 0.8698546886444092
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:14] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.40212059020996094
# [2024/09/14 14:09:14] ppocr DEBUG: cls num  : 11, elapsed : 0.07558751106262207
# [2024/09/14 14:09:16] ppocr DEBUG: rec_res num  : 11, elapsed : 1.2397818565368652
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:16] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.4032776355743408
# [2024/09/14 14:09:16] ppocr DEBUG: cls num  : 9, elapsed : 0.048284053802490234
# [2024/09/14 14:09:17] ppocr DEBUG: rec_res num  : 9, elapsed : 0.46046876907348633
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:17] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.34003424644470215
# [2024/09/14 14:09:17] ppocr DEBUG: cls num  : 8, elapsed : 0.046332359313964844
# [2024/09/14 14:09:17] ppocr DEBUG: rec_res num  : 8, elapsed : 0.3942563533782959
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:18] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.2765047550201416
# [2024/09/14 14:09:18] ppocr DEBUG: cls num  : 6, elapsed : 0.027550220489501953
# [2024/09/14 14:09:19] ppocr DEBUG: rec_res num  : 6, elapsed : 0.8124477863311768
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:19] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.292417049407959
# [2024/09/14 14:09:19] ppocr DEBUG: cls num  : 12, elapsed : 0.030162811279296875
# [2024/09/14 14:09:23] ppocr DEBUG: rec_res num  : 12, elapsed : 3.7753522396087646
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:23] ppocr DEBUG: dt_boxes num : 10, elapsed : 0.27797889709472656
# [2024/09/14 14:09:23] ppocr DEBUG: cls num  : 10, elapsed : 0.04950356483459473
# [2024/09/14 14:09:24] ppocr DEBUG: rec_res num  : 10, elapsed : 0.7363424301147461
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:25] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.2768561840057373
# [2024/09/14 14:09:25] ppocr DEBUG: cls num  : 14, elapsed : 0.041481971740722656
# [2024/09/14 14:09:25] ppocr DEBUG: rec_res num  : 14, elapsed : 0.8359098434448242
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:26] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.2815377712249756
# [2024/09/14 14:09:26] ppocr DEBUG: cls num  : 26, elapsed : 0.07031607627868652
# [2024/09/14 14:09:28] ppocr DEBUG: rec_res num  : 26, elapsed : 1.9801850318908691
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:28] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.4219839572906494
# [2024/09/14 14:09:29] ppocr DEBUG: cls num  : 13, elapsed : 0.08631253242492676
# [2024/09/14 14:09:30] ppocr DEBUG: rec_res num  : 13, elapsed : 1.0946025848388672
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.27611660957336426
# [2024/09/14 14:09:30] ppocr DEBUG: cls num  : 1, elapsed : 0.01515960693359375
# [2024/09/14 14:09:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10125088691711426
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:30] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2959885597229004
# [2024/09/14 14:09:31] ppocr DEBUG: cls num  : 13, elapsed : 0.06382393836975098
# [2024/09/14 14:09:31] ppocr DEBUG: rec_res num  : 13, elapsed : 0.902442455291748
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:32] ppocr DEBUG: dt_boxes num : 13, elapsed : 0.2788429260253906
# [2024/09/14 14:09:32] ppocr DEBUG: cls num  : 13, elapsed : 0.046929121017456055
# [2024/09/14 14:09:33] ppocr DEBUG: rec_res num  : 13, elapsed : 1.0256202220916748
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:33] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.2829930782318115
# [2024/09/14 14:09:33] ppocr DEBUG: cls num  : 7, elapsed : 0.031555891036987305
# [2024/09/14 14:09:34] ppocr DEBUG: rec_res num  : 7, elapsed : 0.38683462142944336
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:34] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.3056154251098633
# [2024/09/14 14:09:34] ppocr DEBUG: cls num  : 11, elapsed : 0.06423759460449219
# [2024/09/14 14:09:35] ppocr DEBUG: rec_res num  : 11, elapsed : 0.6990318298339844
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:35] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.27536487579345703
# [2024/09/14 14:09:35] ppocr DEBUG: cls num  : 18, elapsed : 0.04778909683227539
# [2024/09/14 14:09:36] ppocr DEBUG: rec_res num  : 18, elapsed : 0.9714932441711426
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:37] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.2976706027984619
# [2024/09/14 14:09:37] ppocr DEBUG: cls num  : 27, elapsed : 0.10037541389465332
# [2024/09/14 14:09:38] ppocr DEBUG: rec_res num  : 27, elapsed : 1.6548397541046143
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:39] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.28312087059020996
# [2024/09/14 14:09:39] ppocr DEBUG: cls num  : 25, elapsed : 0.09824275970458984
# [2024/09/14 14:09:41] ppocr DEBUG: rec_res num  : 25, elapsed : 1.7398724555969238
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:41] ppocr DEBUG: dt_boxes num : 90, elapsed : 0.46513891220092773
# [2024/09/14 14:09:42] ppocr DEBUG: cls num  : 90, elapsed : 0.3433723449707031
# [2024/09/14 14:09:48] ppocr DEBUG: rec_res num  : 90, elapsed : 6.2231199741363525
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:48] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.2741057872772217
# [2024/09/14 14:09:48] ppocr DEBUG: cls num  : 8, elapsed : 0.05216622352600098
# [2024/09/14 14:09:49] ppocr DEBUG: rec_res num  : 8, elapsed : 0.4119875431060791
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:49] ppocr DEBUG: dt_boxes num : 46, elapsed : 0.30150938034057617
# [2024/09/14 14:09:49] ppocr DEBUG: cls num  : 46, elapsed : 0.1361527442932129
# [2024/09/14 14:09:52] ppocr DEBUG: rec_res num  : 46, elapsed : 2.2422447204589844
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:52] ppocr DEBUG: dt_boxes num : 35, elapsed : 0.28598880767822266
# [2024/09/14 14:09:52] ppocr DEBUG: cls num  : 35, elapsed : 0.12268829345703125
# [2024/09/14 14:09:54] ppocr DEBUG: rec_res num  : 35, elapsed : 2.313802480697632
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:55] ppocr DEBUG: dt_boxes num : 40, elapsed : 0.43261265754699707
# [2024/09/14 14:09:55] ppocr DEBUG: cls num  : 40, elapsed : 0.1684868335723877
# [2024/09/14 14:09:59] ppocr DEBUG: rec_res num  : 40, elapsed : 3.4508779048919678
# Data successfully saved to /content/save.csv
# [2024/09/14 14:09:59] ppocr DEBUG: dt_boxes num : 46, elapsed : 0.2909054756164551
# [2024/09/14 14:09:59] ppocr DEBUG: cls num  : 46, elapsed : 0.12038969993591309
# [2024/09/14 14:10:01] ppocr DEBUG: rec_res num  : 46, elapsed : 2.0842254161834717
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:02] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.2866365909576416
# [2024/09/14 14:10:02] ppocr DEBUG: cls num  : 18, elapsed : 0.05011463165283203
# [2024/09/14 14:10:03] ppocr DEBUG: rec_res num  : 18, elapsed : 1.0413577556610107
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:03] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.388094425201416
# [2024/09/14 14:10:03] ppocr DEBUG: cls num  : 17, elapsed : 0.07193636894226074
# [2024/09/14 14:10:04] ppocr DEBUG: rec_res num  : 17, elapsed : 1.0464179515838623
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:05] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.2910161018371582
# [2024/09/14 14:10:05] ppocr DEBUG: cls num  : 15, elapsed : 0.0681769847869873
# [2024/09/14 14:10:06] ppocr DEBUG: rec_res num  : 15, elapsed : 1.337693452835083
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:06] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.20410394668579102
# [2024/09/14 14:10:07] ppocr DEBUG: cls num  : 15, elapsed : 0.057771921157836914
# [2024/09/14 14:10:08] ppocr DEBUG: rec_res num  : 15, elapsed : 1.0991706848144531
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:08] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.1693863868713379
# [2024/09/14 14:10:08] ppocr DEBUG: cls num  : 12, elapsed : 0.051403045654296875
# [2024/09/14 14:10:09] ppocr DEBUG: rec_res num  : 12, elapsed : 0.8356034755706787
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:09] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.42511463165283203
# [2024/09/14 14:10:09] ppocr DEBUG: cls num  : 6, elapsed : 0.026793718338012695
# [2024/09/14 14:10:10] ppocr DEBUG: rec_res num  : 6, elapsed : 0.37866735458374023
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:10] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.5698873996734619
# [2024/09/14 14:10:11] ppocr DEBUG: cls num  : 23, elapsed : 0.14836931228637695
# [2024/09/14 14:10:12] ppocr DEBUG: rec_res num  : 23, elapsed : 1.4775676727294922
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:12] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.2723982334136963
# [2024/09/14 14:10:12] ppocr DEBUG: cls num  : 12, elapsed : 0.03346681594848633
# [2024/09/14 14:10:13] ppocr DEBUG: rec_res num  : 12, elapsed : 0.8998358249664307
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:14] ppocr DEBUG: dt_boxes num : 17, elapsed : 0.2783825397491455
# [2024/09/14 14:10:14] ppocr DEBUG: cls num  : 17, elapsed : 0.052549123764038086
# [2024/09/14 14:10:15] ppocr DEBUG: rec_res num  : 17, elapsed : 0.9548397064208984
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:15] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.29403138160705566
# [2024/09/14 14:10:15] ppocr DEBUG: cls num  : 27, elapsed : 0.10053730010986328
# [2024/09/14 14:10:17] ppocr DEBUG: rec_res num  : 27, elapsed : 1.5696094036102295
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:17] ppocr DEBUG: dt_boxes num : 48, elapsed : 0.2984492778778076
# [2024/09/14 14:10:17] ppocr DEBUG: cls num  : 48, elapsed : 0.1156158447265625
# [2024/09/14 14:10:20] ppocr DEBUG: rec_res num  : 48, elapsed : 2.593930721282959
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:20] ppocr DEBUG: dt_boxes num : 37, elapsed : 0.2968273162841797
# [2024/09/14 14:10:21] ppocr DEBUG: cls num  : 37, elapsed : 0.12347173690795898
# [2024/09/14 14:10:23] ppocr DEBUG: rec_res num  : 37, elapsed : 2.652193784713745
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:24] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.4333171844482422
# [2024/09/14 14:10:24] ppocr DEBUG: cls num  : 4, elapsed : 0.05221819877624512
# [2024/09/14 14:10:24] ppocr DEBUG: rec_res num  : 4, elapsed : 0.4798576831817627
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:25] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.2845749855041504
# [2024/09/14 14:10:25] ppocr DEBUG: cls num  : 4, elapsed : 0.016554832458496094
# [2024/09/14 14:10:26] ppocr DEBUG: rec_res num  : 4, elapsed : 0.8195137977600098
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:26] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.2770566940307617
# [2024/09/14 14:10:26] ppocr DEBUG: cls num  : 9, elapsed : 0.054453372955322266
# [2024/09/14 14:10:27] ppocr DEBUG: rec_res num  : 9, elapsed : 0.9677605628967285
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:27] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.2823622226715088
# [2024/09/14 14:10:27] ppocr DEBUG: cls num  : 21, elapsed : 0.06298613548278809
# [2024/09/14 14:10:29] ppocr DEBUG: rec_res num  : 21, elapsed : 1.112945318222046
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:29] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2805805206298828
# [2024/09/14 14:10:29] ppocr DEBUG: cls num  : 5, elapsed : 0.03918647766113281
# [2024/09/14 14:10:30] ppocr DEBUG: rec_res num  : 5, elapsed : 0.5458054542541504
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:30] ppocr DEBUG: dt_boxes num : 34, elapsed : 0.28955984115600586
# [2024/09/14 14:10:30] ppocr DEBUG: cls num  : 34, elapsed : 0.11426758766174316
# [2024/09/14 14:10:32] ppocr DEBUG: rec_res num  : 34, elapsed : 1.5799171924591064
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:32] ppocr DEBUG: dt_boxes num : 15, elapsed : 0.1538681983947754
# [2024/09/14 14:10:32] ppocr DEBUG: cls num  : 15, elapsed : 0.05080556869506836
# [2024/09/14 14:10:33] ppocr DEBUG: rec_res num  : 15, elapsed : 0.7670979499816895
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:33] ppocr DEBUG: dt_boxes num : 22, elapsed : 0.326984167098999
# [2024/09/14 14:10:33] ppocr DEBUG: cls num  : 22, elapsed : 0.06398129463195801
# [2024/09/14 14:10:35] ppocr DEBUG: rec_res num  : 22, elapsed : 1.455089807510376
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:35] ppocr DEBUG: dt_boxes num : 18, elapsed : 0.434464693069458
# [2024/09/14 14:10:35] ppocr DEBUG: cls num  : 18, elapsed : 0.07033038139343262
# [2024/09/14 14:10:38] ppocr DEBUG: rec_res num  : 18, elapsed : 2.593867063522339
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:38] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.331195592880249
# [2024/09/14 14:10:38] ppocr DEBUG: cls num  : 2, elapsed : 0.049036264419555664
# [2024/09/14 14:10:39] ppocr DEBUG: rec_res num  : 2, elapsed : 0.16205453872680664
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:39] ppocr DEBUG: dt_boxes num : 21, elapsed : 0.28057432174682617
# [2024/09/14 14:10:39] ppocr DEBUG: cls num  : 21, elapsed : 0.1027073860168457
# [2024/09/14 14:10:41] ppocr DEBUG: rec_res num  : 21, elapsed : 1.9096143245697021
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:41] ppocr DEBUG: dt_boxes num : 39, elapsed : 0.2517416477203369
# [2024/09/14 14:10:41] ppocr DEBUG: cls num  : 39, elapsed : 0.1067812442779541
# [2024/09/14 14:10:44] ppocr DEBUG: rec_res num  : 39, elapsed : 2.7433011531829834
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:44] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.26781702041625977
# [2024/09/14 14:10:45] ppocr DEBUG: cls num  : 3, elapsed : 0.016017436981201172
# [2024/09/14 14:10:45] ppocr DEBUG: rec_res num  : 3, elapsed : 0.42727160453796387
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:45] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.3372817039489746
# [2024/09/14 14:10:45] ppocr DEBUG: cls num  : 23, elapsed : 0.08331418037414551
# [2024/09/14 14:10:48] ppocr DEBUG: rec_res num  : 23, elapsed : 2.0869293212890625
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:48] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.3028523921966553
# [2024/09/14 14:10:48] ppocr DEBUG: cls num  : 9, elapsed : 0.03429579734802246
# [2024/09/14 14:10:49] ppocr DEBUG: rec_res num  : 9, elapsed : 0.6166837215423584
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:49] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.591771125793457
# [2024/09/14 14:10:49] ppocr DEBUG: cls num  : 2, elapsed : 0.042192935943603516
# [2024/09/14 14:10:50] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2879669666290283
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:50] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.40909266471862793
# [2024/09/14 14:10:50] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/09/14 14:10:50] ppocr DEBUG: rec_res num  : 0, elapsed : 2.6226043701171875e-06
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:51] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.4029068946838379
# [2024/09/14 14:10:51] ppocr DEBUG: cls num  : 12, elapsed : 0.05054187774658203
# [2024/09/14 14:10:52] ppocr DEBUG: rec_res num  : 12, elapsed : 1.0026772022247314
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:52] ppocr DEBUG: dt_boxes num : 33, elapsed : 0.3032834529876709
# [2024/09/14 14:10:52] ppocr DEBUG: cls num  : 33, elapsed : 0.08916115760803223
# [2024/09/14 14:10:54] ppocr DEBUG: rec_res num  : 33, elapsed : 1.8762879371643066
# Data successfully saved to /content/save.csv
# [2024/09/14 14:10:55] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.2853507995605469
# [2024/09/14 14:10:55] ppocr DEBUG: cls num  : 5, elapsed : 0.037947654724121094
# [2024/09/14 14:10:55] ppocr DEBUG: rec_res num  : 5, elapsed : 0.7621147632598877
# Data successfully saved to /content/save.csv

# %%
print(df['image_link'][53])
# Out:
# https://m.media-amazon.com/images/I/613BeFNwHcL.jpg

# %%
import shutil

# Path to your folder
folder_path = '/content/test_output'
# Path where the zip file will be saved
zip_file_path = folder_path + '.zip'

# Create a zip file
shutil.make_archive(folder_path, 'zip', folder_path)
# Out:
# '/content/test_output.zip'

# %%
print(len(os.listdir('/content/test_output')))
# Out:
# 97

# %%
df['tags'] = df['image_link'].apply(lambda x: x[36:-4])

# %%
df = df.sort_values(by = 'tags')
df
# Out:
#                                            image_link  group_id  entity_name  \
# 20  https://m.media-amazon.com/images/I/31EvJszFVf...    731432  item_weight
# 70  https://m.media-amazon.com/images/I/413FQB0ZML...    308856  item_weight
# 71  https://m.media-amazon.com/images/I/41EjbFu-+y...    308856  item_weight
# 46  https://m.media-amazon.com/images/I/41wvffSxB4...    299791  item_weight
# 26  https://m.media-amazon.com/images/I/51WsuKKAVr...    866516  item_weight
# ..                                                ...       ...          ...
# 57  https://m.media-amazon.com/images/I/915w0BdW-g...    993359  item_weight
# 8   https://m.media-amazon.com/images/I/91Cma3Rzse...    731432  item_weight
# 12  https://m.media-amazon.com/images/I/91LPf6OjV9...    281678  item_weight
# 47  https://m.media-amazon.com/images/I/91cErO-KbL...    237000  item_weight
# 19  https://m.media-amazon.com/images/I/91prZeizZn...    731432  item_weight
#
#       entity_value         tags
# 20        200 gram  31EvJszFVfL
# 70      2 kilogram  413FQB0ZMLL
# 71     10 kilogram  41EjbFu-+yL
# 46       15.5 gram  41wvffSxB4L
# 26      158.0 gram  51WsuKKAVrL
# ..             ...          ...
# 57        500 gram  915w0BdW-gL
# 8   1400 milligram  91Cma3RzseL
# 12      3.53 ounce  91LPf6OjV9L
# 47      200.0 gram  91cErO-KbLL
# 19        200 gram  91prZeizZnL
#
# [99 rows x 5 columns]

# %%
df['text'] = ''

# Iterate over the files in the output folder
for file_name in os.listdir('/content/test_output'):
    if file_name.endswith(".txt"):
        # Get the unique id by removing '.txt' from the file name
        file_unique_id = file_name.split(".txt")[0]

        # Check if the file_unique_id matches any unique id in the DataFrame
        if file_unique_id in df['tags'].values:
            # Read the content of the .txt file
            with open(os.path.join('/content/test_output', file_name), 'r') as file:
                file_content = file.read()

            # Store the content in the 'ocr' column where the unique_id matches
            df.loc[df['tags'] == file_unique_id, 'text'] = file_content

# %%
df
# Out:
#                                            image_link  group_id  entity_name  \
# 20  https://m.media-amazon.com/images/I/31EvJszFVf...    731432  item_weight
# 70  https://m.media-amazon.com/images/I/413FQB0ZML...    308856  item_weight
# 71  https://m.media-amazon.com/images/I/41EjbFu-+y...    308856  item_weight
# 46  https://m.media-amazon.com/images/I/41wvffSxB4...    299791  item_weight
# 26  https://m.media-amazon.com/images/I/51WsuKKAVr...    866516  item_weight
# ..                                                ...       ...          ...
# 57  https://m.media-amazon.com/images/I/915w0BdW-g...    993359  item_weight
# 8   https://m.media-amazon.com/images/I/91Cma3Rzse...    731432  item_weight
# 12  https://m.media-amazon.com/images/I/91LPf6OjV9...    281678  item_weight
# 47  https://m.media-amazon.com/images/I/91cErO-KbL...    237000  item_weight
# 19  https://m.media-amazon.com/images/I/91prZeizZn...    731432  item_weight
#
#       entity_value         tags  \
# 20        200 gram  31EvJszFVfL
# 70      2 kilogram  413FQB0ZMLL
# 71     10 kilogram  41EjbFu-+yL
# 46       15.5 gram  41wvffSxB4L
# 26      158.0 gram  51WsuKKAVrL
# ..             ...          ...
# 57        500 gram  915w0BdW-gL
# 8   1400 milligram  91Cma3RzseL
# 12      3.53 ounce  91LPf6OjV9L
# 47      200.0 gram  91cErO-KbLL
# 19        200 gram  91prZeizZnL
#
#                                                  text
# 20                         Glucon-0 \n9.4in \n23cm \n
# 70  2kg  \nREE  \nCANINE  \nCREEK  \n"LIFE PRESERV...
# 71          CREEK \nClub \n13891 \nlu \nUSA \nATED \n
# 46                    50cm \nEST  \nANDS  \n3.5cm  \n
# 26  "Product Size" 15926CM\nQty./Ctn. 96PCS\n"Cart...
# ..                                                ...
# 57  MIILOr MIILOr\nFENNEL FENNEL\n"H9 qla" "H9 qla...
# 8       100% \n    HIGHEST \n    QUALITY \n Horbaa...
# 12       R. \n "Helps in"    "Helps in" \n osteoar...
# 47  "KNTTED MATERIAL" \n"Super soft and comfortabl...
# 19  FREE "Regular 200gpack"    \nGlucon-D Glucon-D...
#
# [99 rows x 6 columns]

# %%
df.to_csv('outputs.csv')

# %%
import re
import pandas as pd
import numpy as np

# Given entity_unit_map
entity_unit_map = {
    'width': {'centimetre', 'foot', 'inch', 'metre', 'millimetre', 'yard'},
    'depth': {'centimetre', 'foot', 'inch', 'metre', 'millimetre', 'yard'},
    'height': {'centimetre', 'foot', 'inch', 'metre', 'millimetre', 'yard'},
    'item_weight': {'gram', 'kilogram', 'microgram', 'milligram', 'ounce', 'pound', 'ton'},
    'maximum_weight_recommendation': {'gram', 'kilogram', 'microgram', 'milligram', 'ounce', 'pound', 'ton'},
    'voltage': {'kilovolt', 'millivolt', 'volt'},
    'wattage': {'kilowatt', 'watt'},
    'item_volume': {'centilitre', 'cubic foot', 'cubic inch', 'cup', 'decilitre', 'fluid ounce',
                    'gallon', 'imperial gallon', 'litre', 'microlitre', 'millilitre', 'pint', 'quart', 'ounce'}
}

# Function to generate unit variations
def generate_unit_variations(unit):
    variations = set()
    # Add the unit itself
    variations.add(unit)
    # Add plural form
    if not unit.endswith('s'):
        variations.add(unit + 's')
    # Common abbreviations and variations
    abbreviations = {
        'gram': ['g', 'gm', 'gr'],
        'kilogram': ['kg', 'kgs', 'kilo'],
        'milligram': ['mg', 'mgs'],
        'microgram': ['mcg'],
        'ounce': ['oz', 'fl oz'],
        'pound': ['lb', 'lbs'],
        'ton': ['t'],
        'metre': ['m', 'meter', 'meters'],
        'centimetre': ['cm', 'centimeter', 'centimeters'],
        'millimetre': ['mm', 'millimeter', 'millimeters'],
        'inch': ['in', 'inches', '"'],
        'foot': ['ft', "'"],
        'yard': ['yd', 'yds'],
        'volt': ['v', 'volts'],
        'kilovolt': ['kv', 'kilovolts'],
        'millivolt': ['mv', 'millivolts'],
        'watt': ['w', 'watts'],
        'kilowatt': ['kw', 'kilowatts'],
        'litre': ['l', 'liter', 'liters'],
        'millilitre': ['ml', 'milliliter', 'milliliters'],
        'microlitre': ['µl', 'microliter', 'microliters'],
        'gallon': ['gal', 'gals'],
        'pint': ['pt', 'pts'],
        'quart': ['qt', 'qts'],
        'cup': ['cups'],
        'fluid ounce': ['fl oz', 'fluid oz'],
        'cubic foot': ['ft³', 'cubic ft'],
        'cubic inch': ['in³', 'cubic in'],
        'centilitre': ['cl', 'centiliter', 'centiliters'],
        'decilitre': ['dl', 'deciliter', 'deciliters'],
        'imperial gallon': ['imp gal', 'imperial gal'],
        'ounce': ['oz', 'oz.', 'ounce', 'ounces'],
    }
    if unit in abbreviations:
        variations.update(abbreviations[unit])
    # Handle capitalization variations
    variations.update({v.upper() for v in variations})
    variations.update({v.capitalize() for v in variations})
    return variations

# Function to create regex patterns for each entity
def create_entity_patterns(entity_unit_map):
    entity_patterns = {}
    for entity, units in entity_unit_map.items():
        unit_variations = set()
        for unit in units:
            unit_variations.update(generate_unit_variations(unit))
        # Create regex pattern for units
        unit_pattern = r'|'.join(sorted(map(re.escape, unit_variations), key=len, reverse=True))
        # Regex pattern to find numbers and units in various formats
        pattern = re.compile(
            rf'(?i)(?P<number>\b\d+(?:[\.,]\d+)?|\b(?:{"|".join(NUMBER_WORDS.keys())})(?:\s+(?:{"|".join(NUMBER_WORDS.keys())}))*\b)[\s\-]*'
            rf'(?P<unit>{unit_pattern})\b|'
            rf'(?P<unit_before>{unit_pattern})[\s\-]*(?P<number_before>\b\d+(?:[\.,]\d+)?|\b(?:{"|".join(NUMBER_WORDS.keys())})(?:\s+(?:{"|".join(NUMBER_WORDS.keys())}))*\b)'
        )
        entity_patterns[entity] = pattern
    return entity_patterns

# Number words mapping
NUMBER_WORDS = {
    'zero': 0,
    'one': 1,
    'two': 2,
    'three': 3,
    'four': 4,
    'five': 5,
    'six': 6,
    'seven':7,
    'eight':8,
    'nine':9,
    'ten':10,
    'eleven':11,
    'twelve':12,
    'thirteen':13,
    'fourteen':14,
    'fifteen':15,
    'sixteen':16,
    'seventeen':17,
    'eighteen':18,
    'nineteen':19,
    'twenty':20,
    'thirty':30,
    'forty':40,
    'fifty':50,
    'sixty':60,
    'seventy':70,
    'eighty':80,
    'ninety':90,
    'hundred':100,
    'thousand':1000,
    'million':1000000,
    'billion':1000000000
}

# Function to convert number words to numeric value
def text2int(textnum):
    tokens = re.findall(r'\w+', textnum.lower())
    current = result = 0
    for word in tokens:
        if word not in NUMBER_WORDS:
            continue
        scale = NUMBER_WORDS[word]
        if scale >= 100:
            current *= scale
        else:
            current += scale
    return str(current + result)

# Function to extract entity values from text
def extract_entity_values(row, patterns):
    text = row['text']
    entity = row['entity_name']
    if pd.isna(text) or text.strip() == '':
        return ''
    pattern = patterns.get(entity)
    if not pattern:
        return ''
    matches = pattern.finditer(text)
    for match in matches:
        if match.group('number') and match.group('unit'):
            number = match.group('number')
            unit = match.group('unit')
        elif match.group('number_before') and match.group('unit_before'):
            number = match.group('number_before')
            unit = match.group('unit_before')
        else:
            continue
        # Convert number words to digits
        if not re.match(r'\d', number):
            number = text2int(number)
        # Replace comma with dot for decimals
        number = number.replace(',', '.')
        return f"{number} {unit}"
    return ''


df = pd.read_csv('/content/outputs.csv')

# Create patterns
patterns = create_entity_patterns(entity_unit_map)

# Apply extraction function
df['extracted_value'] = df.apply(extract_entity_values, axis=1, patterns=patterns)

# %%
df_x = df['extracted_value'].to_csv('sample_X.csv')

# %%
len(df[df['extracted_value']==""])
# Out:
# 37

# %%
df_z = pd.read_csv('/content/extracted_values_100_rows.csv')

# %%
df_z['tags'] = df['tags']

# %%
df_z.to_csv('100_extracted_with_tags.csv')

# %%
df_z
# Out:
#     Unnamed: 0 extracted_value
# 0            0             NaN
# 1            1            2 kg
# 2            2             NaN
# 3            3             NaN
# 4            4           158 g
# ..         ...             ...
# 94          94           500 g
# 95          95         1400 MG
# 96          96             NaN
# 97          97             NaN
# 98          98             NaN
#
# [99 rows x 2 columns]

# %%
df_100 = pd.read_csv('/content/100rows.csv')

# %%
df_100['tags'] = df_100['image_link'].apply(lambda x: x[36:-4])
df_100['extracted_value'] = df_z['extracted_value']

# %%
df_100
# Out:
#                                            image_link  group_id  entity_name  \
# 0   https://m.media-amazon.com/images/I/61I9XdN6OF...    748919  item_weight
# 1   https://m.media-amazon.com/images/I/71gSRbyXmo...    916768  item_volume
# 2   https://m.media-amazon.com/images/I/61BZ4zrjZX...    459516  item_weight
# 3   https://m.media-amazon.com/images/I/612mrlqiI4...    459516  item_weight
# 4   https://m.media-amazon.com/images/I/617Tl40LOX...    731432  item_weight
# ..                                                ...       ...          ...
# 94  https://m.media-amazon.com/images/I/61Dq3LRei9...    523149  item_weight
# 95  https://m.media-amazon.com/images/I/71XK5d3Oh9...    416664      wattage
# 96  https://m.media-amazon.com/images/I/61kyBEJYDe...    459516  item_weight
# 97  https://m.media-amazon.com/images/I/71uQmsTESv...    459516  item_weight
# 98  https://m.media-amazon.com/images/I/71jG8BOi4W...    241608  item_weight
#
#       entity_value         tags extracted_value
# 0       500.0 gram  61I9XdN6OFL             NaN
# 1          1.0 cup  71gSRbyXmoL            2 kg
# 2       0.709 gram  61BZ4zrjZXL             NaN
# 3       0.709 gram  612mrlqiI4L             NaN
# 4   1400 milligram  617Tl40LOXL           158 g
# ..             ...          ...             ...
# 94   10.0 kilogram  61Dq3LRei9L           500 g
# 95       49.0 watt  71XK5d3Oh9L         1400 MG
# 96   500 milligram  61kyBEJYDeL             NaN
# 97   500 milligram  71uQmsTESvL             NaN
# 98       16.0 gram  71jG8BOi4WL             NaN
#
# [99 rows x 6 columns]

# %%
df_100.to_csv('100_extracted_with_tags_complete.csv')
